# %%
from flask import Flask, render_template, request
from anpr import read_img, read_video
import os

app = Flask(__name__)

BASE_PATH = os.getcwd()
UPLOAD_PATH = os.path.join(BASE_PATH, '/Users/Lenovo/Desktop/fyp/upload')

# %%
# !pip install easyocr

# %%
def array_to_string(arr):
    if(len(arr) == 0):
        return "No detections found"
    res = '<br>'.join([str(elem.replace(" ","")) for elem in arr])
    return res

# %%
@app.route('/', methods=['POST', 'GET'])
def index():
    if request.method == 'POST':

        upload_video = None
        upload_img = None

        for file in request.files:
            filename = request.files[file].filename
            extension = os.path.splitext(filename)[1].lower()

            if extension in ['.mp4', '.mov']:
                upload_video = request.files[file]
            elif extension in ['.jpg', '.jpeg', '.png']:
                upload_img = request.files[file]
                
        print(upload_video)
        print(upload_img)

        if (upload_video != None):
            filename = upload_video.filename
            path_save = os.path.join(UPLOAD_PATH, filename)
            upload_video.save(path_save)
            text = read_video(path_save)
            text = array_to_string(text)
            print("video",text)
            return render_template('index.html', upload=True, text=text)

        if (upload_img != None):
            filename = upload_img.filename
            path_save = os.path.join(UPLOAD_PATH, filename)
            upload_img.save(path_save)
            text = read_img(path_save)
            text = array_to_string(text)
            print(path_save)
            print("img", text)
            return render_template('index.html', upload=True, text=text)

    return render_template('index.html', upload=False, text='')


if __name__ == "__main__":
    app.run(debug=False)
# Out:
#  * Serving Flask app '__main__'
#  * Debug mode: off
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on http://127.0.0.1:5000
# Press CTRL+C to quit
# 127.0.0.1 - - [05/Jun/2023 10:58:06] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [05/Jun/2023 10:58:07] "GET /static/styles.css HTTP/1.1" 304 -
# 127.0.0.1 - - [05/Jun/2023 10:58:07] "GET /static/copy.png HTTP/1.1" 304 -
# 127.0.0.1 - - [05/Jun/2023 10:58:07] "GET /static/index.js HTTP/1.1" 304 -
# 127.0.0.1 - - [05/Jun/2023 10:58:07] "GET /favicon.ico HTTP/1.1" 404 -
# 127.0.0.1 - - [05/Jun/2023 10:58:14] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [05/Jun/2023 10:58:14] "GET /static/styles.css HTTP/1.1" 304 -
# 127.0.0.1 - - [05/Jun/2023 10:58:14] "GET /static/copy.png HTTP/1.1" 304 -
# 127.0.0.1 - - [05/Jun/2023 10:58:14] "GET /static/index.js HTTP/1.1" 304 -
# <FileStorage: 'irl2.mp4' ('video/mp4')>
# None
# ['MHOLhX5291', 'Jh03 CH 3647']
# ['MHO LhX529 _', 'Mh03 Ch J647']
# ['NHO LhX5291', 'Mh03 GH J647']
# ['MHOLhX529 1', 'Mh103 CH 3647']
# ['MHO LhX5291', 'Mho3 Ch 1647']
# ['MHO LHX529', 'M4oJ (h J65']
# ['MHO LhX529', 'Mhu ch J6I']
# ['NHOLhX5291', 'Khda Gh 6']
# ['MHOLHX5291', 'MhiddchiJea']
# ['MhoLhX5291', 'Yha Gh']
# ['MHoLHX529']
# ['MHoLHX529']
# ['MHO LHX529']
# ['MHOLHX529']
# ['MHOLhX5291']
# ['HhoLhX529']
# ['Mho LhX5291']
# ['MHoLHX5291']
# ['MhO LhX5291']
# ['Mho LhX529"']
# ['Mho LhX5291']
# ['WHo LHX5291', '']
# ['Mho LhX 5291', 'Mh W901']
# ['Mho LhX5291', 'Mh']
# ['Hho LHX529]', '']
# ['Mh#wee', 'NHOLHX529']
# ['MhOLHX529]', 'Wka']
# ['MhO LhX5291', '']
# ['Ho LHX529]', '']
# ['no number', '']
# ['MA47']
# ['']
# ['']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '', '']
# ['', '']
# ['', '']
# ['', '', '']
# ['']
# ['']
# ['']
# ['']
# ['']
# ['', '', '']
# ['']
# ['']
# ['']
# ['', '', 'Nt & BAR']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '44010494']
# ['Mh47 wa4', 'AHeed']
# ['Vhemch', '']
# ['MA', 'Ldaeh']
# ['MA W698', 'UOch i']
# ['Vmn [e', 'W808']
# ['MA W59087', 'Uhid GhaO']
# ['Mh W 6987', 'Nhocheo']
# ['MH 47 W 5987', 'VhOIckah']
# ['Mh 47 W 6987', 'Mhul GHeEO']
# ['Mh 47 W 5987', '"ech']
# ['Mh W 6907', '{Aotcy #6e']
# ['Mh 47 W 598', 'IT CkS']
# 127.0.0.1 - - [05/Jun/2023 11:11:29] "POST / HTTP/1.1" 200 -
# 127.0.0.1 - - [05/Jun/2023 11:11:29] "GET /static/styles.css HTTP/1.1" 304 -
# 127.0.0.1 - - [05/Jun/2023 11:11:29] "GET /static/copy.png HTTP/1.1" 304 -
# 127.0.0.1 - - [05/Jun/2023 11:11:29] "GET /static/index.js HTTP/1.1" 304 -
# ['Mh 47 W', 'Wich>n']
# Unable to read video
# MH0LHX5291
# JH03CH3647
# MH0LHX529_
# MH03CH1647
# NH0LHX5291
# MH03GH1647
# MH0LHX5291
# MH10ECH3647
# MH0LHX5291
# MH03CH1647
# MH0LHX529
# MA01(H165
# MH0LHX529
# MHUCHJ6I
# NH0LHX5291
# KHDAGH6
# MH0LHX5291
# MH1DDCH1134
# MH0LHX5291
# YHAGH
# MH0LHX529
# MH0LHX529
# MH0LHX529
# MH0LHX529
# MH0LHX5291
# HH0LHX529
# MH0LHX5291
# MH0LHX5291
# MH0LHX5291
# MH0LHX529"
# MH0LHX5291
# WH0LHX5291
#
# MH0LHX5291
# MHW901
# MH0LHX5291
# MH
# HH0LHX5291
#
# MH#WEE
# NH0LHX529
# MH0LHX5291
# WKA
# MH0LHX5291
#
# HOLHXS291
#
# NONUMBER
#
# MA47
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# NT&BAR
#
#
#
#
#
#
#
#
#
#
#
#
#
# 44010494
# MH47WA4
# AHEED
# VHEMCH
#
# MA
# LDAEH
# MAW698
# UOCHI
# VMN[E
# W808
# MAW59087
# UHIDGHAO
# MHW6987
# NHOCHEO
# MH47WS987
# VHOICKAH
# MH47WG987
# MHULGH330
# MH47WS987
# "ECH
# MHW6907
# {A07CY#63
# MH47W598
# ITCKS
# MH47W
# WICH>N
# video JH03CH3647<br>MH47WS987<br>MH47W598<br>MH03GH1647<br>MH47WG987<br>MH03CH1647<br>MH47WA4
# None
# <FileStorage: 'ind2.jpg' ('image/jpeg')>
# 127.0.0.1 - - [05/Jun/2023 11:13:34] "POST / HTTP/1.1" 200 -
# 127.0.0.1 - - [05/Jun/2023 11:13:34] "GET /static/styles.css HTTP/1.1" 304 -
# 127.0.0.1 - - [05/Jun/2023 11:13:34] "GET /static/copy.png HTTP/1.1" 304 -
# 127.0.0.1 - - [05/Jun/2023 11:13:34] "GET /static/index.js HTTP/1.1" 304 -
# C:/Users/Lenovo/Desktop/fyp/upload\ind2.jpg
# img MHI2DEL1433
# None
# <FileStorage: 'ind2.jpg' ('image/jpeg')>
# 127.0.0.1 - - [05/Jun/2023 11:14:22] "POST / HTTP/1.1" 200 -
# 127.0.0.1 - - [05/Jun/2023 11:14:22] "GET /static/styles.css HTTP/1.1" 304 -
# 127.0.0.1 - - [05/Jun/2023 11:14:22] "GET /static/copy.png HTTP/1.1" 304 -
# 127.0.0.1 - - [05/Jun/2023 11:14:22] "GET /static/index.js HTTP/1.1" 304 -
# C:/Users/Lenovo/Desktop/fyp/upload\ind2.jpg
# img MHI2DEL1433
# <FileStorage: 'TEST3.mp4' ('video/mp4')>
# None
# []
# []
# []
# ['']
# ['30']
# ['5030']
# ['lcd5030']
# ['J20CD5030']
# ['RJZOCD5030']
# ['IND RJZOCD5030']
# ['IND RUZOCD5030']
# ['RJZ0CD5030']
# ['RJZOCD5030']
# ['RJZOCD5030']
# ['RJZOCD5030']
# ['RJZOcd5030]']
# ['RJ2OCD5030]']
# ['RJZOCD5030']
# ['RJZOCD5030']
# ['RJ2OCD5030']
# ['RJZOcD5030']
# ['IND RJZOCD5030']
# ['RJZOCD5030']
# ['IND RJ2OCD5030]']
# ['IND RJZOCD5030']
# ['IND RJ2OCD5030']
# ['IND RJ2OcD5030']
# ['IND RJZOCD5030']
# ['IND RJZOCD5030']
# 127.0.0.1 - - [05/Jun/2023 11:15:22] "POST / HTTP/1.1" 200 -
# 127.0.0.1 - - [05/Jun/2023 11:15:22] "GET /static/styles.css HTTP/1.1" 304 -
# 127.0.0.1 - - [05/Jun/2023 11:15:22] "GET /static/copy.png HTTP/1.1" 304 -
# 127.0.0.1 - - [05/Jun/2023 11:15:22] "GET /static/index.js HTTP/1.1" 304 -
# ['IND R J20CD6030]']
# Unable to read video
#
# 30
# 5030
# LCD5030
# JZ0CDS030
# RJ20CD5030
# INDRJZ0CD5030
# INDRUZ0CD5030
# RJ20CD5030
# RJ20CD5030
# RJ20CD5030
# RJ20CD5030
# RJ20CD50301
# RJ20CD50301
# RJ20CD5030
# RJ20CD5030
# RJ20CD5030
# RJ20CD5030
# INDRJZ0CD5030
# RJ20CD5030
# INDRJZ0CD50301
# INDRJZ0CD5030
# INDRJZ0CD5030
# INDRJZ0CD5030
# INDRJZ0CD5030
# INDRJZ0CD5030
# INDRJZ0CD60301
# video RJ20CD5030
# None
# <FileStorage: 'Saitama3.jpg' ('image/jpeg')>
# 127.0.0.1 - - [05/Jun/2023 11:21:33] "POST / HTTP/1.1" 200 -
# 127.0.0.1 - - [05/Jun/2023 11:21:34] "GET /static/styles.css HTTP/1.1" 304 -
# 127.0.0.1 - - [05/Jun/2023 11:21:34] "GET /static/copy.png HTTP/1.1" 304 -
# 127.0.0.1 - - [05/Jun/2023 11:21:34] "GET /static/index.js HTTP/1.1" 304 -
# C:/Users/Lenovo/Desktop/fyp/upload\Saitama3.jpg
# img No detections found
# None
# <FileStorage: 'Saitama3.jpg' ('image/jpeg')>
# 127.0.0.1 - - [05/Jun/2023 11:21:52] "POST / HTTP/1.1" 200 -
# 127.0.0.1 - - [05/Jun/2023 11:21:52] "GET /static/styles.css HTTP/1.1" 304 -
# 127.0.0.1 - - [05/Jun/2023 11:21:52] "GET /static/copy.png HTTP/1.1" 304 -
# 127.0.0.1 - - [05/Jun/2023 11:21:52] "GET /static/index.js HTTP/1.1" 304 -
# C:/Users/Lenovo/Desktop/fyp/upload\Saitama3.jpg
# img No detections found

# %%
# %tb
